# %% [markdown]
# # Barton Springs Salamanders & Watershed Quality Report
# ### Benjamin Goad, Michelle Gelman, Nick Hoang, Daphne Lopez

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime,date as dt
import sklearn as sk

# %%
rawData  = pd.DataFrame(pd.read_csv("Barton_Springs_Salamanders_DO_and_Flow.csv"))
rawData = pd.get_dummies(rawData, columns = ['TIME_NULL'])
print(rawData.columns)
for row in rowData:
    print(row.datatype())

ID_FEATURE = "SITE_NAME"

rawData.sample(n = 1000)
# Out:
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'QC_TYPE', 'TIME_NULL_N',
#        'TIME_NULL_Y'],
#       dtype='object')
# /var/folders/mr/4cnzqd010hgdhl63_hgs_2w80000gn/T/ipykernel_28122/4152066726.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   rawData  = pd.DataFrame(pd.read_csv("Barton_Springs_Salamanders_DO_and_Flow.csv"))
#           WATERSHED             SAMPLE_DATE                         SITE_NAME  \
# 9735   Barton Creek  09/30/2005 10:55:00 AM               Upper Barton Spring
# 15272  Barton Creek  07/13/2007 10:02:00 AM                      Eliza Spring
# 2849   Barton Creek  05/23/2003 09:26:00 AM                      Eliza Spring
# 20106  Barton Creek  08/28/2008 11:00:00 AM                     Barton Spring
# 29349  Barton Creek  11/30/2010 11:35:00 AM               Upper Barton Spring
# ...             ...                     ...                               ...
# 426    Barton Creek  11/17/1998 12:00:00 PM                     Barton Spring
# 25747  Barton Creek  05/27/2010 12:00:00 AM                     Barton Spring
# 46920  Barton Creek  08/28/2014 11:30:00 AM                     Barton Spring
# 23651  Barton Creek  11/19/2009 01:44:00 PM  Old Mill (Sunken Gardens) Spring
# 48035  Barton Creek  05/24/2017 02:04:00 PM               Upper Barton Spring
#
#        LON_DD_WGS84  LAT_DD_WGS84 SITE_TYPE         MEDIUM     PARAM_TYPE  \
# 9735     -97.773782     30.263594    Spring  Benthic Cover    Salamanders
# 15272    -97.770061     30.264246    Spring  Benthic Cover    Salamanders
# 2849     -97.770061     30.264246    Spring  Benthic Cover    Salamanders
# 20106    -97.770980     30.263535    Spring  Benthic Cover    Salamanders
# 29349    -97.773782     30.263594    Spring  Benthic Cover    Salamanders
# ...             ...           ...       ...            ...            ...
# 426      -97.770980     30.263535    Spring   Ground Water  Flow/Rainfall
# 25747    -97.770980     30.263535    Spring  Benthic Cover    Salamanders
# 46920    -97.770980     30.263535    Spring  Benthic Cover      Physicals
# 23651    -97.768076     30.263585    Spring  Benthic Cover    Salamanders
# 48035    -97.773782     30.263594    Spring        Habitat    Salamanders
#
#                                                PARAMETER QUALIFIER  ...  \
# 9735               BARTON SPGS SALMNDR  (ADULT) > 1 INCH       NaN  ...
# 15272   AUSTIN BLIND SLMNDR  (>=2IN.) IN VEGETATION/MOSS       NaN  ...
# 2849              AUSTIN BLIND SALMNDR  (ADULT) > 1 INCH       NaN  ...
# 20106    AUSTIN BLIND SLMNDR  (1-2IN.) IN COBBLE/BOULDER       NaN  ...
# 29349  BARTON SPRINGS SLMNDR (1-2IN.) ON EXPOSED SUBS...       NaN  ...
# ...                                                  ...       ...  ...
# 426                                                 FLOW       NaN  ...
# 25747               BARTON SPRINGS SLMNDR  (TOTAL <1IN.)       NaN  ...
# 46920                                       AREA SAMPLED       NaN  ...
# 23651   BARTON SPRINGS SLMNDR (1-2IN.) IN COBBLE/BOULDER       NaN  ...
# 48035               BARTON SPRINGS SLMNDR  (TOTAL <1IN.)       NaN  ...
#
#                         SAMPLE_ID SAMPLE_SITE_NO                METHOD  \
# 9735                    Section I            183     VISUAL ASSESSMENT
# 15272                    Quad III            428     VISUAL ASSESSMENT
# 2849                    I NW QUAD            428     VISUAL ASSESSMENT
# 20106                 Main Spring             35     VISUAL ASSESSMENT
# 29349                           V            183     VISUAL ASSESSMENT
# ...                           ...            ...                   ...
# 426                           NaN             35               UNKNOWN
# 25747          Little Main Spring             35     VISUAL ASSESSMENT
# 46920                 Main Spring             35  MEASURING TAPE/RULER
# 23651                          CW            422     VISUAL ASSESSMENT
# 48035  183-SC-Upper Barton Spring            183     VISUAL ASSESSMENT
#
#       QC_FLAG                                          PROJECT DATA_REF_NO  \
# 9735        U                        Barton Springs Salamander     2738321
# 15272       U                        Barton Springs Salamander     1450807
# 2849        U                        Barton Springs Salamander     1690207
# 20106       U                        Barton Springs Salamander     1542156
# 29349       U                        Barton Springs Salamander     1868525
# ...       ...                                              ...         ...
# 426         U                             Barton Springs TPDES      441215
# 25747       U                        Barton Springs Salamander     1745882
# 46920       U                        Barton Springs Salamander     2426968
# 23651       U                        Barton Springs Salamander     1724293
# 48035       U  Barton Spring Austin Blind Salamander Cap-Recap     2715486
#
#       SAMPLE_REF_NO QC_TYPE  TIME_NULL_N  TIME_NULL_Y
# 9735         287055     NaN            1            0
# 15272        307046     NaN            1            0
# 2849         226700     NaN            1            0
# 20106        318250     NaN            1            0
# 29349        358664     NaN            1            0
# ...             ...     ...          ...          ...
# 426           68872     NaN            1            0
# 25747        351091     NaN            0            1
# 46920        480529     NaN            1            0
# 23651        346451     NaN            1            0
# 48035        516175     NaN            1            0
#
# [1000 rows x 23 columns]
