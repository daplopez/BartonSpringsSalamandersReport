# %% [markdown]
# # Barton Springs Salamanders & Watershed Quality Report
# ### Benjamin Goad, Michelle Gelman, Nick Hoang, Daphne Lopez

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime,date as dt
import sklearn as sk

# %% [markdown]
# ### Data Prep
# Read in the data set and print out the head

# %%
rawData  = pd.DataFrame(pd.read_csv("Barton_Springs_Salamanders_DO_and_Flow.csv"))
print(rawData.columns)

ID_FEATURE = "SITE_NAME"

rawData.head(1000)
# Out:
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# /var/folders/mr/4cnzqd010hgdhl63_hgs_2w80000gn/T/ipykernel_29938/3513658504.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   rawData  = pd.DataFrame(pd.read_csv("Barton_Springs_Salamanders_DO_and_Flow.csv"))
#         WATERSHED             SAMPLE_DATE                         SITE_NAME  \
# 0    Barton Creek  07/06/1990 12:00:00 AM                     Barton Spring
# 1    Barton Creek  07/01/1991 12:00:00 AM                     Barton Spring
# 2    Barton Creek  08/02/1991 12:00:00 AM                     Barton Spring
# 3    Barton Creek  10/11/1991 12:00:00 AM                     Barton Spring
# 4    Barton Creek  06/04/1992 11:00:00 AM                     Barton Spring
# ..            ...                     ...                               ...
# 995  Barton Creek  04/12/2001 12:00:00 AM                      Eliza Spring
# 996  Barton Creek  04/12/2001 12:00:00 AM                      Eliza Spring
# 997  Barton Creek  04/12/2001 12:00:00 AM                      Eliza Spring
# 998  Barton Creek  04/12/2001 12:00:00 AM                      Eliza Spring
# 999  Barton Creek  04/16/2001 11:05:00 AM  Old Mill (Sunken Gardens) Spring
#
#      LON_DD_WGS84  LAT_DD_WGS84 SITE_TYPE         MEDIUM     PARAM_TYPE  \
# 0      -97.770980     30.263535    Spring  Surface Water         Oxygen
# 1      -97.770980     30.263535    Spring  Surface Water         Oxygen
# 2      -97.770980     30.263535    Spring  Surface Water         Oxygen
# 3      -97.770980     30.263535    Spring  Surface Water         Oxygen
# 4      -97.770980     30.263535    Spring  Surface Water         Oxygen
# ..            ...           ...       ...            ...            ...
# 995    -97.770061     30.264246    Spring  Benthic Cover    Salamanders
# 996    -97.770061     30.264246    Spring  Benthic Cover    Salamanders
# 997    -97.770061     30.264246    Spring  Benthic Cover    Salamanders
# 998    -97.770061     30.264246    Spring  Benthic Cover    Salamanders
# 999    -97.768076     30.263585    Spring   Ground Water  Flow/Rainfall
#
#                                     PARAMETER QUALIFIER  ...     FILTER  \
# 0                            DISSOLVED OXYGEN       NaN  ...  Dissolved
# 1                            DISSOLVED OXYGEN       NaN  ...  Dissolved
# 2                            DISSOLVED OXYGEN       NaN  ...  Dissolved
# 3                            DISSOLVED OXYGEN       NaN  ...  Dissolved
# 4                            DISSOLVED OXYGEN       NaN  ...  Dissolved
# ..                                        ...       ...  ...        ...
# 995   AUSTIN BLIND SLMNDR (<1IN.)  (JUVENILE)       NaN  ...      Total
# 996    AUSTIN BLIND SALMNDR  (ADULT) > 1 INCH       NaN  ...      Total
# 997               SALAMANDER (UNKNOWN LENGTH)       NaN  ...      Total
# 998  AUSTIN BLIND SALAMANDER (UNKNOWN LENGTH)       NaN  ...      Total
# 999                                      FLOW       NaN  ...      Total
#
#     SAMPLE_ID SAMPLE_SITE_NO                 METHOD  QC_FLAG  \
# 0         NaN             35                UNKNOWN        U
# 1         NaN             35          HACH TEST KIT        U
# 2         NaN             35          HACH TEST KIT        U
# 3         NaN             35          HACH TEST KIT        U
# 4         NaN             35                UNKNOWN        U
# ..        ...            ...                    ...      ...
# 995       NaN            428      VISUAL ASSESSMENT        U
# 996       NaN            428      VISUAL ASSESSMENT        U
# 997       NaN            428      VISUAL ASSESSMENT        U
# 998       NaN            428      VISUAL ASSESSMENT        U
# 999       NaN            422  USGS FLOW MEASUREMENT        U
#
#                        PROJECT DATA_REF_NO SAMPLE_REF_NO  TIME_NULL  QC_TYPE
# 0              Water Watch Dog     2387519        479314          Y      NaN
# 1              Water Watch Dog     1053022         67681          Y      NaN
# 2              Water Watch Dog      557211         67682          Y      NaN
# 3              Water Watch Dog     1052978         67677          Y      NaN
# 4              Water Watch Dog     2335102        450308          N      NaN
# ..                         ...         ...           ...        ...      ...
# 995  Barton Springs Salamander     1705157        342910          Y      NaN
# 996  Barton Springs Salamander     1705158        342910          Y      NaN
# 997  Barton Springs Salamander     1680711        342910          Y      NaN
# 998  Barton Springs Salamander     1705163        342910          Y      NaN
# 999                Groundwater      930894        110779          N      NaN
#
# [1000 rows x 22 columns]

# %% [markdown]
# - Create new dataset using sample ID as the index
# - Aggregate different PARAM_TYPEs and incorporate them as features in the new data set

# %% [markdown]
# ## Feature Engineering Plan
# - [ ] aggregate sample IDS by parameter types:
#     - [ ] get result and unit for each paramater type
#     - [ ] do cleanintg for null values
#     - [ ] print out a scatter plot for each paratamer_type(check for outliers before normalizing)
#     - [ ] print out statistics on each (std, mean, var -> maybe add each as a new column)
#     - [ ] groupBy time_null-> see how many records dont have a date. do a time series plot for result + time for each salamander parameter
# ## What data might we need?
#  - how do we condiser the other paramater types? We could maybe see the days when samples were collected, and add salamander paramater as a new feature. Groupby site name?
#  - how do salamander poplations vary at different types?
#  - what paramater types have a (+/-) correlation with salamnder populations?
#  - do any of the paramater types have an affect on the salamnder sizes? does the season explain it, or is it something about the paramater type at that site?
#  - maybe we could get a data set with mineral content or weather data? what about water levels?
# - [ ] Don't need qualifier, sample IDs, filter, don't need sample_id, sample_site_no,

# %%
print(len(rawData))
groupedData = rawData.groupby('PARAM_TYPE')
#salamanderData = groupedData[groupedData['PARAM_TYPE'] == 'Salamanders']
groupedData[['PARAM_TYPE','RESULT', 'UNIT']].head(49466)
groupedData.head().std()
groupedData.mean()
#groupedData.get_group('Salamanders')
#groupedData.size()
#print(rawData.columns)
#print(groupedData.columns)
#print(rawData["PARAM_TYPE"].isna().sum())
# dataset w/ uneeded columns removed

#Check our data
dups = rawData["LON_DD_WGS84"].unique()
dupSites = rawData["SAMPLE_SITE_NO"].unique()
dupSitesName = rawData["SITE_NAME"].unique()
#this one is mostly null
qual = rawData["QUALIFIER"].isna().sum()
mediums = rawData["MEDIUM"].unique()
paramTypes = rawData["PARAM_TYPE"].unique()
methods = rawData["METHOD"].unique()
params = rawData["PARAMETER"].unique()
print(dups)
print(dupSites)
print(dupSitesName)
print(qual)
print(mediums)
print(paramTypes)
print(methods)
print(params)
print(rawData[["METHOD", "PARAM_TYPE", "QUALIFIER"]])

data = rawData.copy()
#Covert time column to time type and remove time collected
print(data["WATERSHED"].unique())
print(type(data["SAMPLE_DATE"]))
date_format = pd.to_datetime(data["SAMPLE_DATE"]).dt.date
data["SAMPLE_DATE"] = date_format
print(type(date_format))
print(type(data["SAMPLE_DATE"]))


#Drop uneeded columns
data.drop(columns= ["LON_DD_WGS84","LAT_DD_WGS84","DATA_REF_NO","PROJECT", "QC_FLAG", "QC_TYPE", "SITE_TYPE", "WATERSHED", "SAMPLE_SITE_NO", "QUALIFIER"], inplace=True)
data.head(10)

#Need to clean null values and also check what is unknown. Does it matter? Does it lead to significant outliers?
print("Missing values:")
print(data.isnull().sum())
# remove rows with missing sampleIDs, Filter, and Result
data2 = data.copy()
data2 = data2.dropna(subset=['SAMPLE_ID', 'FILTER', 'RESULT'])
print("Missing values:")
print(data2.isnull().sum())

#Does it impact the quality of data if the QU
# Out:
# 49466
# [-97.77097968 -97.76807574 -97.77006059 -97.7737817  -97.77443041
#  -97.76809893]
# [  35  422  428  183  185 3594]
# ['Barton Spring' 'Old Mill (Sunken Gardens) Spring' 'Eliza Spring'
#  'Upper Barton Spring' 'High Barton Spring'
#  'Old Mill Stream (outflow from Sunken Gardens Pool)']
# 49421
# ['Surface Water' 'Benthic Cover' 'Ground Water' 'Sediment' 'Habitat'
#  'Fish/Salamander']
# ['Oxygen' 'Salamanders' 'Flow/Rainfall' 'Temporal' 'Physicals' 'Spatial']
# ['UNKNOWN' 'HACH TEST KIT' 'VISUAL ASSESSMENT'
#  'HORIBA WATER QUALITY METER' 'TCEQ FLOW SEVERITY' 'MARSH McBIRNEY METER'
#  'VISUAL FLOW ESTIMATION' 'USGS FLOW MEASUREMENT' 'Quanta Probe'
#  'HYDROLAB' 'YSI Probe' 'CALCULATION' 'SATUROMETER' 'MEASURING TAPE/RULER'
#  'LAMOTTE TITRATION KIT' 'Flow Tracker' 'USGS Combined Discharge Rating'
#  'HYDROMETER' 'STOPWATCH' 'EPA 350.3' 'Hach FH950' 'In-Situ Aqua Troll']
# ['DISSOLVED OXYGEN' 'BARTON SPRINGS SLMNDR  (TOTAL <1IN.)'
#  'BARTON SPGS SALMNDR  (ADULT) > 1 INCH' 'SALAMANDER (UNKNOWN LENGTH)'
#  'FLOW SEVERITY CODE (1=NONE;2=LOW;3=NORM;4=FLOOD;5=HIGH;6=DRY)' 'FLOW'
#  'AUSTIN BLIND SLMNDR (<1IN.)  (JUVENILE)'
#  'AUSTIN BLIND SALMNDR  (ADULT) > 1 INCH'
#  'AUSTIN BLIND SALAMANDER (UNKNOWN LENGTH)' 'AUSTIN BLIND SLMNDR (1-2IN.)'
#  'AUSTIN BLIND SLMNDR (>=2IN.)' 'BARTON SPRINGS SLMNDR (TOTAL 1-2IN.)'
#  'BARTON SPRINGS SLMNDR (TOTAL >=2IN.)' 'BASEFLOW'
#  'DISSOLVED OXYGEN % OF SATURATION' 'TOTAL TIME SPENT' 'AREA SAMPLED'
#  'BARTON SPRINGS SLMNDR (>=2IN.) IN VEGETATION/MOSS' 'WATER DEPTH'
#  'AUSTIN BLIND SLMNDR (<1IN.) IN VEGETATION/MOSS'
#  'BARTON SPRINGS SLMNDR (<1IN.) IN COBBLE/BOULDER'
#  'BARTON SPRINGS SLMNDR (<1IN.) IN VEGETATION/MOSS'
#  'BARTON SPRINGS SLMNDR (<1IN.) ON EXPOSED SUBSTRATE'
#  'BARTON SPRINGS SALAMANDER  (ADULT) IN VEGETATED SUBSTRATE'
#  'AUSTIN BLIND SLMNDR (<1IN.) IN COBBLE/BOULDER'
#  'BARTON SPRINGS SALAMANDER  (ADULT) IN ROCK SUBSTRATE'
#  'BARTON SPRINGS SALAMANDER  (ADULT) ON EXPOSED SUBSTRATE'
#  'BARTON SPRINGS SLMNDR (<1IN.) IN LEAF LITTER'
#  'AUSTIN BLIND SALAMANDER  (ADULT) IN VEGETATED SUBSTRATE'
#  'AUSTIN BLIND SLMNDR  (<1IN.) ON EXPOSED SUBSTRATE'
#  'AUSTIN BLIND SALAMANDER  (ADULT) IN ROCK SUBSTRATE'
#  'AUSTIN BLIND SLMNDR  (<1IN.) IN LEAF LITTER'
#  'AUSTIN BLIND SALAMANDER  (ADULT) IN LEAF LITTER SUBSTRATE'
#  'AUSTIN BLIND SALAMANDER  (ADULT) ON EXPOSED SUBSTRATE'
#  'BARTON SPRINGS SALAMANDER  (ADULT) IN LEAF LITTER SUBSTRATE'
#  'BARTON SPRINGS SLMNDR (>=2IN.) IN COBBLE/BOULDER'
#  'BARTON SPRINGS SLMNDR (1-2IN.) IN COBBLE/BOULDER'
#  'BARTON SPRINGS SLMNDR (1-2IN.) IN VEGETATION/MOSS'
#  'AUSTIN BLIND SLMNDR (1- 2IN.) IN VEGETATION/MOSS'
#  'AUSTIN BLIND SLMNDR  (>=2IN.) IN COBBLE/BOULDER'
#  'AUSTIN BLIND SLMNDR  (1-2IN.) IN COBBLE/BOULDER'
#  'AUSTIN BLIND SLMNDR  (>=2IN.) IN VEGETATION/MOSS'
#  'BARTON SPRINGS SLMNDR (>=2IN.) IN LEAF LITTER'
#  'BARTON SPRINGS SLMNDR (1-2IN.) IN LEAF LITTER'
#  'BARTON SPRINGS SLMNDR (1-2IN.) ON EXPOSED SUBSTRATE'
#  'BARTON SPRINGS SLMNDR (>=2IN.) ON EXPOSED SUBSTRATE'
#  'AUSTIN BLIND SLMNDR  (>=2IN.) IN LEAF LITTER'
#  'AUSTIN BLIND SLMNDR  (1-2IN.) IN LEAF LITTER'
#  'AUSTIN BLIND SLMNDR (>=2IN.) ON EXPOSED SUBSTRATE'
#  'AUSTIN BLIND SLMNDR (1-2IN.) ON EXPOSED SUBSTRATE'
#  'FLOW PIN MEASUREMENT' 'BARTON SPRINGS SLMNDR (<1IN.) IN ROCK'
#  'SALAMANDERS NOT PHOTGRAPHED 1-2 INCHES'
#  'SALAMANDERS NOT PHOTGRAPHED <1 INCH'
#  'SALAMANDERS NOT PHOTGRAPHED >2 INCHES'
#  'SALAMANDERS PHOTGRAPHED 1-2 INCHES' 'SALAMANDERS PHOTGRAPHED <1 INCH'
#  'SALAMANDERS PHOTGRAPHED >2 INCHES'
#  'NUMBER OF BARTON SPRINGS SALAMANDERS PHOTOGRAPHED'
#  'NUMBER OF AUSTIN BLIND SALAMANDERS PHOTOGRAPHED'
#  'SUM OF BSS SALAMANDERS PER TRANSECT'
#  'SUM OF ABS SALAMANDERS PER TRANSECT']
#                    METHOD   PARAM_TYPE QUALIFIER
# 0                 UNKNOWN       Oxygen       NaN
# 1           HACH TEST KIT       Oxygen       NaN
# 2           HACH TEST KIT       Oxygen       NaN
# 3           HACH TEST KIT       Oxygen       NaN
# 4                 UNKNOWN       Oxygen       NaN
# ...                   ...          ...       ...
# 49461   VISUAL ASSESSMENT  Salamanders       NaN
# 49462   VISUAL ASSESSMENT  Salamanders       NaN
# 49463  In-Situ Aqua Troll       Oxygen       NaN
# 49464  In-Situ Aqua Troll       Oxygen       NaN
# 49465  In-Situ Aqua Troll       Oxygen       NaN
#
# [49466 rows x 3 columns]
# ['Barton Creek']
# <class 'pandas.core.series.Series'>
# /var/folders/mr/4cnzqd010hgdhl63_hgs_2w80000gn/T/ipykernel_29938/3783369770.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   groupedData.head().std()
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# Missing values:
# SAMPLE_DATE         0
# SITE_NAME           0
# MEDIUM              0
# PARAM_TYPE          0
# PARAMETER           0
# RESULT              2
# UNIT                0
# FILTER            695
# SAMPLE_ID        3060
# METHOD              0
# SAMPLE_REF_NO       0
# TIME_NULL           0
# dtype: int64
# Missing values:
# SAMPLE_DATE      0
# SITE_NAME        0
# MEDIUM           0
# PARAM_TYPE       0
# PARAMETER        0
# RESULT           0
# UNIT             0
# FILTER           0
# SAMPLE_ID        0
# METHOD           0
# SAMPLE_REF_NO    0
# TIME_NULL        0
# dtype: int64

# %%
samples = []
parameters = [ID_FEATURE]

for index, row in rawData.iterrows():
    if row[ID_FEATURE] not in samples:
        samples.append(row[ID_FEATURE])
    if row["PARAM_TYPE"] not in parameters:
        parameters.append(row["PARAM_TYPE"])
parameters.append("SITE_NAME")
parameters.append("DATE")
print(len(samples), parameters)
# Out:
# 6 ['SITE_NAME', 'Oxygen', 'Salamanders', 'Flow/Rainfall', 'Temporal', 'Physicals', 'Spatial', 'SITE_NAME', 'DATE']

# %%
def getParameter(sampleDF, feature):
    for index, row in sampleDF.iterrows():
        print(row.index)

# %%
# condition mask
rawData2 = rawData.copy()
rawData2 = rawData2.truncate(after = 900)
mask = rawData2['PARAM_TYPE'] == 'Salamanders'
 
# new dataframe with selected rows
df_new = pd.DataFrame(rawData2[mask])

# number of sample dataframes collected
count = 0 

for index, row in pd.DataFrame(rawData2[rawData2['PARAM_TYPE'] == 'Salamanders']).groupby(["SAMPLE_REF_NO"], dropna=False).mean().iterrows():
    mask = rawData2["SAMPLE_REF_NO"] == index
    sampleDF = pd.DataFrame(rawData2[mask]) # Dataframe containing all features relating so a single sample
    # TODO: Extract available features i.e. for feature in parameters:
    #                                           row with sampleDF[PARAM_TYPE] == feature
    #                                           add(row[Result]) to sampleSeries[feature.index]
    #                                       add(sampleSeries) to samplesDataFrame
    #   
    for feature in parameters:
        getParameter(sampleDF, feature)

    count+=1

print(count, " sample data frames seen")
sampleDF.head()
# Out:
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
# ...
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# Index(['WATERSHED', 'SAMPLE_DATE', 'SITE_NAME', 'LON_DD_WGS84', 'LAT_DD_WGS84',
#        'SITE_TYPE', 'MEDIUM', 'PARAM_TYPE', 'PARAMETER', 'QUALIFIER', 'RESULT',
#        'UNIT', 'FILTER', 'SAMPLE_ID', 'SAMPLE_SITE_NO', 'METHOD', 'QC_FLAG',
#        'PROJECT', 'DATA_REF_NO', 'SAMPLE_REF_NO', 'TIME_NULL', 'QC_TYPE'],
#       dtype='object')
# 157  sample data frames seen
#         WATERSHED             SAMPLE_DATE                         SITE_NAME  \
# 787  Barton Creek  05/30/2000 12:00:00 AM  Old Mill (Sunken Gardens) Spring
# 788  Barton Creek  05/30/2000 12:00:00 AM  Old Mill (Sunken Gardens) Spring
# 789  Barton Creek  05/30/2000 12:00:00 AM  Old Mill (Sunken Gardens) Spring
# 790  Barton Creek  05/30/2000 12:00:00 AM  Old Mill (Sunken Gardens) Spring
#
#      LON_DD_WGS84  LAT_DD_WGS84 SITE_TYPE         MEDIUM   PARAM_TYPE  \
# 787    -97.768076     30.263585    Spring  Benthic Cover  Salamanders
# 788    -97.768076     30.263585    Spring  Benthic Cover  Salamanders
# 789    -97.768076     30.263585    Spring  Benthic Cover  Salamanders
# 790    -97.768076     30.263585    Spring  Benthic Cover  Salamanders
#
#                                    PARAMETER QUALIFIER  ...  FILTER  \
# 787     BARTON SPRINGS SLMNDR  (TOTAL <1IN.)       NaN  ...     NaN
# 788    BARTON SPGS SALMNDR  (ADULT) > 1 INCH       NaN  ...     NaN
# 789  AUSTIN BLIND SLMNDR (<1IN.)  (JUVENILE)       NaN  ...     NaN
# 790   AUSTIN BLIND SALMNDR  (ADULT) > 1 INCH       NaN  ...     NaN
#
#        SAMPLE_ID SAMPLE_SITE_NO             METHOD  QC_FLAG  \
# 787  spring pool            422  VISUAL ASSESSMENT        U
# 788  spring pool            422  VISUAL ASSESSMENT        U
# 789  spring pool            422  VISUAL ASSESSMENT        U
# 790  spring pool            422  VISUAL ASSESSMENT        U
#
#                        PROJECT DATA_REF_NO SAMPLE_REF_NO  TIME_NULL  QC_TYPE
# 787  Barton Springs Salamander     2718177        561548          Y      NaN
# 788  Barton Springs Salamander     2718178        561548          Y      NaN
# 789  Barton Springs Salamander     2718179        561548          Y      NaN
# 790  Barton Springs Salamander     2718180        561548          Y      NaN
#
# [4 rows x 22 columns]

# %%
# df = pd.DataFrame(columns= parameters)

# for sample in samples:
#     #aggregating data for each sample
#     sampleData = dict()
#     for param in parameters:
#       sampleData.update({param : None})
#     sampleData.update({ID_FEATURE: sample})
#     sampleDF = rawData[rawData[ID_FEATURE] == sample]
#     #print(type(sampleDF))
#     for index, row in sampleDF.iterrows():
#         sampleData.update({row["PARAM_TYPE"]: row["RESULT"]})
#         print(row["PARAM_TYPE"], row["RESULT"])
#     print(sampleData)
#     #print(sampleData)
#     df.append(sampleData, ignore_index=True)   
# df.head()

### - not a useful codeblock i dont think, prefer above - ###
# Out:
# Oxygen 64.0
# Oxygen 6.3
# Oxygen 9.0
# Oxygen 10.0
# Oxygen 6.5
# Oxygen 6.6
# Oxygen 6.8
# Oxygen 6.4
# Oxygen 7.0
# Oxygen 7.0
# Oxygen 6.8
# Oxygen 7.5
# Oxygen 7.3
# Oxygen 8.6
# Oxygen 1.0
# Oxygen 7.2
# Oxygen 7.6
# Oxygen 6.8
# Oxygen 7.2
# Oxygen 7.2
# Oxygen 7.2
# Oxygen 6.8
# Oxygen 7.4
# Oxygen 7.3
# Oxygen 7.4
# Oxygen 7.0
# Oxygen 7.2
# Oxygen 6.2
# Oxygen 6.8
# Oxygen 7.0
# Oxygen 6.1
# Oxygen 7.3
# Oxygen 6.8
# Oxygen 7.3
# Oxygen 6.2
# Oxygen 6.2
# Oxygen 6.3
# Oxygen 6.0
# Oxygen 6.0
# Oxygen 5.6
# Oxygen 6.2
# Oxygen 5.6
# Oxygen 5.4
# Oxygen 6.4
# Oxygen 6.3
# Oxygen 6.6
# Oxygen 6.4
# Oxygen 6.0
# Oxygen 6.6
# Oxygen 5.7
# Oxygen 6.6
# Oxygen 6.8
# Oxygen 7.0
# Oxygen 6.3
# Oxygen 6.4
# Oxygen 6.35
# Oxygen 6.1
# Oxygen 6.05
# Oxygen 6.0
# Oxygen 5.6
# Oxygen 5.6
# Oxygen 3.45
# Oxygen 5.78
# Oxygen 6.24
# Oxygen 5.97
# Oxygen 6.1
# Oxygen 5.95
# Oxygen 6.22
# Oxygen 5.32
# Oxygen 5.41
# Oxygen 5.41
# Oxygen 5.41
# Oxygen 5.2
# Oxygen 5.06
# Oxygen 4.86
# Oxygen 5.52
# Oxygen 4.31
# Salamanders 18.0
# Salamanders 16.0
# Salamanders 0.0
# Oxygen 4.47
# Oxygen 5.01
# Salamanders 8.0
# Salamanders 11.0
# Salamanders 0.0
# Oxygen 3.61
# Oxygen 4.47
# Oxygen 5.92
# Oxygen 4.5
# Oxygen 4.55
# Oxygen 4.81
# Oxygen 4.53
# Oxygen 4.62
# Oxygen 4.44
# Oxygen 4.45
# Oxygen 4.56
# Oxygen 4.55
# Oxygen 4.45
# Oxygen 5.52
# Oxygen 5.77
# Oxygen 5.9
# Oxygen 6.09
# Oxygen 5.73
0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 28.0
# Oxygen 5.04
# Flow/Rainfall 29.0
# Salamanders 9.0
# Salamanders 23.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 42.0
# Flow/Rainfall 24.0
# Salamanders 16.0
# Salamanders 15.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 21.0
# Flow/Rainfall 62.0
# Salamanders 4.0
# Salamanders 7.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 55.0
# Flow/Rainfall 41.0
# Flow/Rainfall 32.0
# Salamanders 3.0
# Salamanders 6.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 30.0
# Flow/Rainfall 25.0
# Salamanders 1.0
# Salamanders 6.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 23.0
# Flow/Rainfall 26.0
# Oxygen 4.46
# Salamanders 1.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 24.0
# Oxygen 4.32
# Oxygen 4.84
# Flow/Rainfall 40.0
# Salamanders 2.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 77.0
# Flow/Rainfall 85.0
# Flow/Rainfall 85.0
# Flow/Rainfall 91.0
# Flow/Rainfall 98.0
# Salamanders 7.0
# Salamanders 6.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 100.0
# Flow/Rainfall 102.0
# Oxygen 9.3
# Flow/Rainfall 103.0
# Flow/Rainfall 108.0
# Oxygen 8.26
# Salamanders 0.0
# Salamanders 9.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 104.0
# Oxygen 8.7
# Flow/Rainfall 103.0
# Salamanders 2.0
# Salamanders 8.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 102.0
# Oxygen 7.25
# Flow/Rainfall 84.0
# Flow/Rainfall 102.0
# Oxygen 7.17
# Flow/Rainfall 96.0
# Oxygen 7.14
# Flow/Rainfall 93.0
# Oxygen 6.48
# Salamanders 2.0
# Salamanders 13.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 78.0
# Oxygen 7.08
# Flow/Rainfall 72.0
# Oxygen 6.85
# Flow/Rainfall 77.0
# Salamanders 0.0
# Salamanders 13.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 71.0
# Oxygen 6.67
# Salamanders 6.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 65.0
# Oxygen 6.39
# Flow/Rainfall 90.0
# Oxygen 6.95
# Flow/Rainfall 90.0
# Oxygen 7.18
# Salamanders 1.0
# Salamanders 5.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 7.44
# Flow/Rainfall 105.0
# Oxygen 7.82
# Oxygen 7.57
# Salamanders 2.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 104.0
# Oxygen 7.65
# Salamanders 22.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 96.0
# Oxygen 7.28
# Flow/Rainfall 9.4
# Oxygen 7.33
# Flow/Rainfall 100.0
# Salamanders 15.0
# Salamanders 7.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 95.0
# Oxygen 6.88
# Flow/Rainfall 92.0
# Oxygen 6.63
# Salamanders 9.0
# Salamanders 5.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 87.0
# Oxygen 6.72
# Flow/Rainfall 82.0
# Oxygen 9.76
# Salamanders 15.0
# Salamanders 7.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 77.0
# Oxygen 6.91
# Flow/Rainfall 71.0
# Oxygen 6.48
# Flow/Rainfall 77.0
# Oxygen 5.73
# Flow/Rainfall 100.0
# Oxygen 6.53
# Oxygen 68.8
# Temporal 100.0
# Salamanders 13.0
# Salamanders 13.0
# Temporal 5.0
# Salamanders 1.0
# Salamanders 1.0
# Temporal 40.0
# Salamanders 10.0
# Salamanders 10.0
# Temporal 54.0
# Temporal 10.0
# Flow/Rainfall 97.0
# Oxygen 6.4
# Oxygen 6.92
# Oxygen 5.84
# Oxygen 64.8
# Flow/Rainfall 90.0
# Oxygen 6.48
# Flow/Rainfall 84.0
# Oxygen 6.27
# Temporal 60.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 60.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 33.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 47.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen
0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 8.0
# Salamanders 2.0
# Salamanders 12.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 12.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 171.0
# Spatial 204.0
# Temporal 105.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 15.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.0
# Oxygen 56.6
# Oxygen 6.34
# Oxygen 6.44
# Oxygen 5.8
# Oxygen 66.2
# Flow/Rainfall 86.0
# Oxygen 6.37
# Oxygen 6.0
# Oxygen 68.8
# Flow/Rainfall 83.0
# Oxygen 7.07
# Temporal 128.0
# Salamanders 3.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 32.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 51.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 135.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 40.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 94.0
# Oxygen 6.57
# Flow/Rainfall 90.0
# Oxygen 7.31
# Spatial 180.0
# Temporal 112.0
# Salamanders 4.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Spatial 192.0
# Temporal 80.0
# Salamanders 3.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Spatial 204.0
# Temporal 50.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.2
# Oxygen 73.2
# Spatial 60.0
# Temporal 50.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Spatial 36.0
# Temporal 55.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.0
# Oxygen 78.4
# Flow/Rainfall 70.0
# Oxygen 6.94
# Oxygen 6.0
# Oxygen 71.8
# Oxygen 5.9
# Oxygen 75.6
# Flow/Rainfall 70.0
# Oxygen 7.04
# Physicals 171.0
# Temporal 80.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 1125.0
# Temporal 85.0
# Salamanders 6.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 6.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 90.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 90.0
# Temporal 100.0
# Salamanders 4.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 60.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 67.0
# Oxygen 7.6
# Oxygen 5.6
# Oxygen 73.5
# Oxygen 5.8
# Oxygen 68.2
# Oxygen 6.99
# Oxygen 6.0
# Oxygen 68.2
# Flow/Rainfall 71.0
# Oxygen 5.96
# Oxygen 5.4
# Oxygen 65.2
# Oxygen 5.7
# Oxygen 6.02
# Oxygen 64.1
# Oxygen 0.0
# Oxygen 66.0
# Oxygen 6.61
# Oxygen 72.6
# Oxygen 7.3
# Physicals 1125.0
# Spatial 120.0
# Temporal 96.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 162.0
# Temporal 70.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 171.0
# Temporal 35.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 60.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 12.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.92
# Oxygen 74.8
# Oxygen 7.08
# Oxygen 78.2
# Flow/Rainfall 98.0
# Oxygen 6.97
# Oxygen 7.02
# Oxygen 77.2
# Oxygen 7.02
# Oxygen 75.3
# Flow/Rainfall 99.0
# Oxygen 6.8
# Oxygen 6.54
# Oxygen 73.2
# Flow/Rainfall 104.0
# Oxygen 6.91
# Oxygen 9.26
# Oxygen 101.9
# Oxygen 6.98
# Oxygen 77.1
# Oxygen 7.65
# Flow/Rainfall 93.4
# Oxygen 6.85
# Temporal 225.0
# Salamanders 4.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 2.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 54.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 171.0
# Temporal 100.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 1125.0
# Temporal 121.0
# Salamanders 1.0
# Salamanders 7.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 4.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 162.0
# Temporal 59.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 111.0
# Oxygen 6.83
# Oxygen 6.97
# Oxygen 6.58
# Oxygen 7.05
# Oxygen 78.4
# Physicals 1050.0
# Spatial 180.0
# Temporal 219.0
# Salamanders 6.0
# Salamanders 6.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 6.0
# Salamanders 2.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 2.0
# Salamanders 1.0
# Salamanders 0.0
# Temporal 20.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 400.0
# Spatial 204.0
# Temporal 122.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 26.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 337.5
# Spatial 180.0
# Temporal 92.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 91.0
# Oxygen 6.81
# Flow/Rainfall 83.0
# Oxygen 6.73
# Temporal 119.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals
0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 5.0
# Salamanders 8.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 8.0
# Salamanders 5.0
# Salamanders 0.0
# Salamanders 0.0
# Spatial 121.1
# Temporal 20.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Flow/Rainfall 29.0
# Oxygen 4.91
# Oxygen 5.43
# Oxygen 60.4
# Physicals 1050.0
# Spatial 150.0
# Temporal 446.0
# Salamanders 72.0
# Salamanders 224.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 72.0
# Salamanders 49.0
# Salamanders 175.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 175.0
# Salamanders 49.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 700.0
# Temporal 225.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 400.0
# Spatial 170.4
# Temporal 150.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Spatial 68.0
# Temporal 60.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 30.0
# Oxygen 5.1
# Flow/Rainfall 34.0
# Oxygen 4.76
# Flow/Rainfall 31.0
# Oxygen 5.2
# Flow/Rainfall 20.0
# Flow/Rainfall 23.0
# Oxygen 6.79
# Oxygen 74.2
# Oxygen 5.23
# Oxygen 5.42
# Oxygen 59.8
# Temporal 85.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 1000.0
# Spatial 132.0
# Temporal 280.0
# Salamanders 16.0
# Salamanders 44.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 16.0
# Salamanders 8.0
# Salamanders 36.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 36.0
# Salamanders 8.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 400.0
# Spatial 192.0
# Temporal 69.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 700.0
# Spatial 180.0
# Temporal 179.0
# Salamanders 8.0
# Salamanders 40.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 8.0
# Salamanders 17.0
# Salamanders 23.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 23.0
# Salamanders 17.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 22.0
# Flow/Rainfall 32.0
# Oxygen 5.1
# Oxygen 5.93
# Physicals 700.0
# Spatial 144.0
# Temporal 350.0
# Salamanders 9.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 9.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 400.0
# Spatial 204.0
# Temporal 158.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 1600.0
# Spatial 132.0
# Temporal 505.0
# Salamanders 11.0
# Salamanders 13.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 11.0
# Salamanders 4.0
# Salamanders 9.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 9.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.13
# Oxygen 4.21
# Oxygen 4.74
# Oxygen 53.7
# Physicals 835.0
# Temporal 160.0
# Salamanders 1.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 400.0
# Temporal 49.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 1600.0
# Temporal 291.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 100.0
# Temporal 129.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 4.82
# Oxygen 4.82
# Oxygen 4.78
# Oxygen 4.73
# Physicals 400.0
# Spatial 192.0
# Temporal 85.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 835.0
# Spatial 180.0
# Temporal 296.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 1350.0
# Spatial 132.0
# Temporal 338.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 100.0
# Spatial 84.0
# Temporal 50.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 250.0
# Spatial 48.0
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Spatial 36.0
# Temporal 60.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 22.0
# Oxygen 4.74
# Flow/Rainfall 20.0
# Oxygen 4.61
# Physicals 835.0
# Temporal 235.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 1600.0
# Temporal 335.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 300.0
# Temporal 120.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 400.0
# Temporal 131.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 4.93
# Oxygen 55.4
# Flow/Rainfall 18.0
# Oxygen 4.32
# Oxygen 47.8
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 4.21
# Oxygen 46.5
# Physicals 1350.0
# Temporal 485.0
# Salamanders 3.0
# Salamanders 7.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 7.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 7.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 585.0
# Temporal 119.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 835.0
# Temporal 181.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 250.0
# Temporal 110.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 15.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 4.32
# Flow/Rainfall 23.0
# Oxygen 4.86
# Oxygen 5.01
# Oxygen 57.2
# Physicals 835.0
# Spatial 180.0
# Temporal 135.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 1350.0
# Spatial 36.0
# Spatial 132.0
# Temporal 85.0
# Temporal 449.0
# Salamanders 0.0
# Salamanders 6.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 6.0
# Salamanders 1.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 5.01
# Oxygen 57.2
# Physicals 400.0
# Spatial 192.0
# Temporal 143.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Spatial 72.0
# Temporal 65.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 250.0
# Spatial 72.0
# Temporal 60.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 24.0
# Oxygen 4.54
# Flow/Rainfall 24.0
# Oxygen 4.48
# Physicals 650.0
# Spatial 120.0
# Temporal 211.0
# Salamanders 7.0
# Salamanders 6.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 7.0
# Salamanders 3.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 31.0
# Oxygen 4.96
# Flow/Rainfall 18.6
# Flow/Rainfall 22.5
# Flow/Rainfall 32.0
# Oxygen 5.02
# Flow/Rainfall 46.1
# Flow/Rainfall 54.93
# Oxygen 7.01
# Oxygen 75.0
# Flow/Rainfall 69.0
# Oxygen 7.02
# Oxygen 5.98
# Oxygen 6.11
# Oxygen 67.2
# Physicals 835.0
# Temporal 105.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 100.0
# Temporal 145.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 250.0
# Temporal 78.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 171.0
# Temporal 135.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 45.0
# Salamanders 0.0
# Salamanders 0.0
# ...
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 475.0
# Spatial 15.8
# Temporal 193.0
# Flow/Rainfall 8.3
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 5.91
# Oxygen 67.5
# Physicals 385.0
# Spatial 10.96
# Temporal 150.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 5.77
# Oxygen 65.5
# Flow/Rainfall 5.787000000000001
# Flow/Rainfall 5.497000000000001
# Physicals 385.0
# Spatial 10.69
# Temporal 405.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 5.32
# Oxygen 60.7
# Flow/Rainfall 3.6
# Spatial 3.45
# Flow/Rainfall 3.4
# Spatial 3.47
# Flow/Rainfall 2.9
# Spatial 3.5
# Flow/Rainfall 2.94
# Flow/Rainfall 2.9
# Oxygen 5.02
# Oxygen 57.7
# Flow/Rainfall 2.571
# Physicals 385.0
# Spatial 10.96
# Temporal 315.0
# Salamanders 1.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 1.0
# Salamanders 0.0
# Spatial 3.58
# Flow/Rainfall 1.9
# Physicals 326.8
# Spatial 11.12
# Temporal 261.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 4.2
# Oxygen 49.8
# Spatial 3.68
# Flow/Rainfall 1.22
# Spatial 3.68
# Flow/Rainfall 1.4
# Spatial 3.68
# Flow/Rainfall 1.03
# Physicals 320.0
# Spatial 3.86
# Temporal 305.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 5.2
# Oxygen 58.9
# Physicals 115.5
# Spatial 7.31
# Temporal 160.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 5.71
# Oxygen 69.5
# Physicals 111.5
# Spatial 3.85
# Temporal 38.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 10.0
# Spatial 4.24
# Temporal 10.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 4.7
# Oxygen 53.4
# Physicals 242.0
# Spatial 6.67
# Temporal 80.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 1.09
# Spatial -4.05
# Temporal 10.0
# Flow/Rainfall 1.57
# Physicals 282.0
# Spatial 6.22
# Temporal 85.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 5.68
# Oxygen 63.6
# Physicals 282.0
# Spatial 8.27
# Temporal 55.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.28
# Oxygen 69.0
# Physicals 344.0
# Spatial 9.91
# Temporal 75.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.5
# Oxygen 71.3
# Physicals 470.0
# Spatial 13.15
# Temporal 140.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 7.63
# Oxygen 81.4
# Oxygen 6.0
# Oxygen 67.7
# Physicals 572.0
# Spatial 12.71
# Temporal 154.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.23
# Oxygen 70.2
# Physicals 432.52
# Spatial 12.6
# Temporal 286.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 5.78
# Oxygen 65.1
# Physicals 427.0
# Spatial 11.05
# Temporal 100.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 7.65
# Oxygen 88.0
# Oxygen 4.8
# Physicals 298.0
# Spatial 6.83
# Temporal 184.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 280.0
# Spatial 7.5
# Temporal 120.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 4.2
# Oxygen 4.7
# Physicals 400.0
# Spatial 5.3
# Temporal 218.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 4.4
# Oxygen 4.6
# Oxygen 49.2
# Physicals 383.0
# Spatial 4.71
# Temporal 165.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 311.5
# Spatial 4.54
# Temporal 306.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 4.7
# Oxygen 52.9
# Spatial 4.44
# Flow/Rainfall 0.6
# Flow/Rainfall 0.02
# Physicals 428.0
# Spatial 6.9
# Temporal 290.0
# Salamanders 0.0
# Salamanders 3.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 4.2
# Oxygen 3.0
# Physicals 113.6
# Spatial 3.69
# Temporal 90.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.0
# Physicals 535.5
# Spatial 6.54
# Temporal 156.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.8
# Spatial 10.23
# Temporal 178.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Physicals 427.8
# Spatial 28.28
# Temporal 135.0
# Flow/Rainfall 4.124
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Spatial 4.2
# Temporal 108.0
# Flow/Rainfall 8.18
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 5.17
# Spatial 7.73
# Temporal 105.0
# Flow/Rainfall 0.983
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Temporal 75.0
# Flow/Rainfall 12.245
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Oxygen 6.27
# Temporal 180.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 58.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 56.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 13.52
# Oxygen 6.63
# Temporal 30.0
# Temporal 40.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 18.2
# Oxygen 6.43
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 12.5182
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 1.0
# Salamanders 0.0
# Flow/Rainfall 12.97
# Temporal 27.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 10.04
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Flow/Rainfall 11.04
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 9.02
# Temporal 35.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 1.0
# Salamanders 3.0
# Salamanders 0.0
# Flow/Rainfall 11.273
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 0.0
# Salamanders 4.0
# Salamanders 0.0
# Flow/Rainfall 4.438
# Temporal 60.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 1.0
# Salamanders 3.0
# Salamanders 0.0
# Flow/Rainfall 2.1113
# Temporal 60.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 0.0
# Flow/Rainfall 11.17
# Oxygen 5.74
# Temporal 25.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 2.0
# Salamanders 0.0
# Temporal 25.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 45.0
# Salamanders 1.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 5.6
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 4.47
# Oxygen 5.23
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 2.0
# Salamanders 0.0
# Flow/Rainfall 8.38
# Temporal 20.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 60.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 1.0
# Salamanders 1.0
# Salamanders 2.0
# Salamanders 0.0
# Flow/Rainfall 2.96
# Flow/Rainfall 1.66
# Temporal 20.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 2.0
# Salamanders 0.0
# Flow/Rainfall 2.72
# Temporal 45.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 2.0
# Salamanders 1.0
# Flow/Rainfall 6.65
# Temporal 30.0
# Salamanders 2.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 8.82
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 8.19
# Flow/Rainfall 4.05
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Temporal 30.0
# Salamanders 0.0
# Salamanders 0.0
# Flow/Rainfall 2.7
# {'Sample Number': 'Old Mill Stream (outflow from Sunken Gardens Pool)', 'Oxygen': 5.23, 'Salamanders': 0.0, 'Flow/Rainfall': 2.7, 'Temporal': 30.0, 'Physicals': 427.8, 'Spatial': 7.73, 'SITE_NAME': None, 'DATE': None}
# Empty DataFrame
# Columns: [Sample Number, Oxygen, Salamanders, Flow/Rainfall, Temporal, Physicals, Spatial, SITE_NAME, DATE]
# Index: []
